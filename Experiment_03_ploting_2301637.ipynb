# %% [markdown]
# **Experiment No : 03**
#
# **Aim :**
#
# Learn basics of maplotlib library and its use as visualisation tool in data science pipeline and learn about line plots and scatter plots.
#
# **Theory :**
#
# Matplotlib is a multi-platform data visualization library built on NumPy arrays, and designed to work with the broader SciPy stack.
#
# It was conceived by John Hunter in 2002, originally as a patch to IPython for enabling interactive MATLAB-style plotting via gnuplot from the IPython command line.
#
# One of Matplotlib’s most important features is its ability to play well with many operating systems and graphics backends. Matplotlib supports dozens of backends and output types, which means you can count on it to work regardless of which operating system you are using or which output format you wish.
#
# This cross-platform, everything-to-everyone approach has been one of the great strengths of Matplotlib. It has led to a large user base, which in turn has led to an active developer base and Matplotlib’s powerful tools and ubiquity within the scientific Python world.
#
# In recent years, however, the interface and style of Matplotlib have begun to show their age. Newer tools like ggplot and ggvis in the R language, along with web visualization toolkits based on D3js and HTML5 canvas, often make Matplotlib feel clunky and old-fashioned.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.__version__
# Out:
# '3.10.0'

# %%
#setting ploting style
plt.style.use('classic')

# %%
# %matplotlib inline
import numpy as np
x = np.linspace(0, 10, 1000)

fig = plt.figure()
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# Saving Figures to File
# One nice feature of Matplotlib is the ability to save figures in a wide variety of formats. Saving a figure can be done using the savefig() command. For example, to save the previous figure as a PNG file, you can run this:

# %%
#Save above plot with file named my_figure.png in Current Working Directory
fig.savefig('my_figure.png')

# %%
 #Cross check the folder content
# !ls -lh my_figure.png
# Out:
# -rw-r--r-- 1 root root 45K Feb 24 09:17 my_figure.png

# %%
# use Image package in python to check contents of png file in cwd
from IPython.display import Image
Image('my_figure.png')

# %%
#checking supported file types by matplotlib
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# Matplotlib API Interfaces
#
# A potentially confusing feature of Matplotlib is its dual interfaces: a convenient MATLAB-style state-based interface, and a more powerful object-oriented interface. This section we will review them breifly.
# MATLAB-style Interface
#
# Matplotlib was originally written as a Python alternative for MATLAB users, and much of its syntax reflects that fact. The MATLAB-style tools are contained in the pyplot (plt) interface. See the example inthe code cell below.

# %%
plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %% [markdown]
# This interface is stateful: It keeps track of the "current" figure and axes, which are where all plt commands are applied.
#
# You can get a reference to these using the plt.gcf() (get current figure) and plt.gca() (get current axes) routines.
#
# While this stateful interface is fast and convenient for simple plots, it is easy to run into problems.
#
# For example, once the second panel is created, how can we go back and add something to the first? This interface does have a solution but it is not a easy solution.
#
# **Object-oriented interface of Matplotlib**
#
# The object-oriented interface can nicely handle more complicated plots, and for when you want more control over your figure.
#
# Rather than depending on some notion of an "active" figure or axes, in the object-oriented interface the plotting functions are methods of explicit Figure and Axes objects.
#
# To re-create the previous plot using this style of plotting, you might do the following:

# %%
#First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
# The difference is as small as switching plt.plot() to ax.plot().
#
# Now we start exploring different types of plots in following sections.
#
# **Simple Line Plots**
#
# Perhaps the simplest of all plots is the visualization of a single function y = f(x).
#
# Here we will take a first look at creating a simple plot of this type.

# %%
# Import all necesssary libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# Print available styles to help identify valid options
print("Available Matplotlib styles:", plt.style.available)

# Correcting the plotting style to a valid one, e.g., 'seaborn-v0_8' or 'ggplot'
# As per the matplotlib documentation and common practice, many seaborn styles are prefixed with 'seaborn-v0_8' after Matplotlib 3.8
# Alternatively, you might use 'ggplot' or 'default' if a specific seaborn style isn't available.
plt.style.use('seaborn-v0_8')
# Out:
# Available Matplotlib styles: ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# creating objects of figure and axes.
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# In Matplotlib, the figure (an instance of the class plt.Figure) can be thought of as a single container that contains all the objects representing axes, graphics, text, and labels.
#
# The axes (an instance of the class plt.Axes) is what we see above: a bounding box with ticks and labels, which will eventually contain the plot elements that make up our visualization.
#
# Once we have created an axes, we can use the ax.plot function to plot some data.

# %%
# we will plot sine curve using ax.plot function
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %%
plt.plot(x, np.sin(x))   #shown in blue
plt.plot(x, np.sin(2*x)) #Shown in green
plt.plot(x,(x**(1/2))/2) #Shown in red

# %% [markdown]
# **Adjusting the Plot: Line Colors and Styles**
#
# The first adjustment you might wish to make to a plot is to control the line colors and styles. The plt.plot() function takes additional arguments that can be used to specify these. To adjust the color, you can use the color keyword, which accepts a string argument representing virtually any imaginable color. The color can be specified in a variety of ways:

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %% [markdown]
# **Adjusting the Plot: Axes Limits**
#
# Matplotlib does a decent job of choosing default axes limits for your plot, but sometimes it's nice to have finer control. The most basic way to adjust axis limits is to use the plt.xlim() and plt.ylim() methods:

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %%
# Reverse the Axis Limit
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %% [markdown]
# **Labeling Plots**
#
# As the last piece of this section, we'll briefly look at the labeling of plots: titles, axis labels, and simple legends.
#
# Titles and axis labels are the simplest such labels—there are methods that can be used to quickly set them:

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %% [markdown]
# When multiple lines are being shown within a single axes, it can be useful to create a plot legend that labels each line type.
#
# Again, Matplotlib has a built-in way of quickly creating such a legend. It is done via the (you guessed it) plt.legend() method.
#
# Though there are several valid ways of using this, I find it easiest to specify the label of each line using the label keyword of the plot function:

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %% [markdown]
# **Simple Scatter Plots**
#
# Another commonly used plot type is the simple scatter plot, a close cousin of the line plot. Instead of points being joined by line segments, here the points are represented individually with a dot, circle, or other shape.

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %% [markdown]
# **Scatter Plots with plt.scatter**
#
# A second, more powerful method of creating scatter plots is the plt.scatter function, which can be used very similarly to the plt.plot function:

# %%
y = np.sin(x)
plt.scatter(x, y, marker='o');

# Consider this code for scatter plot

rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show color scale

# %% [markdown]
# Question Answer Section
#
# Q1.List any 2 python APIs that are used for Plotting Graphs.
#
# Ans:
#     Matplotlib (specifically matplotlib.pyplot): This is explicitly used throughout the notebook for various types of plots like line plots and scatter plots.
#     NumPy: While primarily a numerical computing library, it's fundamental for generating data (np.linspace, np.random.RandomState, np.sin, np.cos) that is then visualized using Matplotlib. Although not a plotting library itself, its close integration makes it an essential partner in plotting workflows.

# %% [markdown]
# Q2.Name 2 important machnisms used for accesssing Matplotlib API.
# Ans:  The notebook highlights two important mechanisms for accessing the Matplotlib API:
#
#   1.MATLAB-style Interface: This interface uses the matplotlib.pyplot module (often imported as plt) and is state-based, keeping track of the 'current' figure and axes. It's convenient for simpler plots.
#
#   2.Object-oriented Interface: This more powerful interface involves creating explicit Figure and Axes objects, and then calling plotting methods directly on these objects. This provides finer control, especially for more complex plots

# %% [markdown]
# 3.Create a collection of 100 random normal numbers with parameter mean 30, sd 4 store it in object summer_temp

# %%
import numpy as np

# Create a collection of 100 random normal numbers
# with mean 30 and standard deviation 4
summer_temp = np.random.normal(loc=30, scale=4, size=100)

# Display the first few values and some statistics to verify
print("First 5 values of summer_temp:", summer_temp[:5])
print("Mean of summer_temp:", np.mean(summer_temp))
print("Standard deviation of summer_temp:", np.std(summer_temp))
# Out:
# First 5 values of summer_temp: [30.55487041 34.20695677 23.96571527 24.17124518 33.52279033]
# Mean of summer_temp: 29.861033696515435
# Standard deviation of summer_temp: 3.835965589159434

# %% [markdown]
#  I will create a collection of 100 random normal numbers with a mean of 30 and a standard deviation of 4, and store them in an object called summer_temp.
#  The code in cell 2b42b264 executed successfully. It generated 100 random normal numbers for summer_temp with a mean of approximately 30 and a standard deviation of about 4, as requested. The output shows:
#
# The first 5 values of the generated summer_temp array.
#   The calculated mean of the summer_temp array, which is very close to 30.
#   The calculated standard deviation of the summer_temp array, which is close to 4.

# %% [markdown]
# Q4.Sort above set and store in object sorted_summer_temp
# Ans:

# %%
# Sort the summer_temp array and store it in sorted_summer_temp
sorted_summer_temp = np.sort(summer_temp)

print("First 5 sorted summer temperatures:", sorted_summer_temp[:5])
print("Last 5 sorted summer temperatures:", sorted_summer_temp[-5:])
# Out:
# First 5 sorted summer temperatures: [21.45254649 22.63288538 22.7992296  23.23363673 23.40043443]
# Last 5 sorted summer temperatures: [36.2603644  36.30128878 36.83805606 37.67882323 38.08100902]

# %%
# Calculate the average of 25 consecutive elements from sorted_summer_temp
# Since summer_temp has 100 elements, we'll have 100/25 = 4 averages.
window_size = 25
x = [np.mean(sorted_summer_temp[i:i + window_size])
     for i in range(0, len(sorted_summer_temp), window_size)]
x = np.array(x)

print("Averages of 25 consecutive elements (x):"), x
# Out:
# Averages of 25 consecutive elements (x):
# (None, array([24.88654629, 28.45462323, 31.39008216, 34.71288311]))

# %%
# Plot the object x as a line plot
plt.figure(figsize=(8, 5))
plt.plot(x, marker='o', linestyle='-', color='purple')
plt.title('Average of 25 Consecutive Sorted Summer Temperatures')
plt.xlabel('Group Index (each group is 25 elements)')
plt.ylabel('Average Temperature')
plt.grid(True)
plt.xticks(range(len(x))) # Ensure all group indices are shown
plt.show()

# %% [markdown]
# From the line plot of the averages of 25 consecutive sorted elements, you can observe:
#
# *   **Trend**: The plot will show a clear increasing trend. Since we sorted `summer_temp` first, taking averages of consecutive blocks will naturally result in increasing average values.
# *   **Data Distribution/Spread**: It gives a coarse-grained view of the temperature distribution. Each point represents a segment of the overall data range.
# *   **Range**: The first point in the plot will indicate the average of the lowest 25 temperatures, and the last point will indicate the average of the highest 25 temperatures. This shows the range covered by the data in these averaged segments.

# %% [markdown]
# Q5.Store average of 25 consecutive elements from sorted_summer_temp into object x and plot it as a line plot. What kind of information do u get about the data?

# %%
# Calculate the average of 25 consecutive elements from sorted_summer_temp
# Since summer_temp has 100 elements, we'll have 100/25 = 4 averages.
window_size = 25
x = [np.mean(sorted_summer_temp[i:i + window_size])
     for i in range(0, len(sorted_summer_temp), window_size)]
x = np.array(x)

print("Averages of 25 consecutive elements (x): ", x)
# Out:
# Averages of 25 consecutive elements (x):  [24.88654629 28.45462323 31.39008216 34.71288311]

# %% [markdown]
# ## Calculate Averages for Sorted Data
#
# ### Subtask:
# Calculate the average of 25 consecutive elements from the `sorted_summer_temp` array and store the results in a new object named `x`.

# %% [markdown]
# **Reasoning**:
# To calculate the average of 25 consecutive elements from the `sorted_summer_temp` array and store them in `x`, I will implement the specified steps in a code block: define `window_size`, iterate through `sorted_summer_temp` to get 25-element slices, calculate the mean of each slice, store these means in a list, convert the list to a NumPy array `x`, and then print `x`.

# %%
plt.figure(figsize=(8, 5))
plt.scatter(range(len(y)), y, color='blue', s=100, alpha=0.7, edgecolors='w')
plt.title('Scatter Plot of Averages of 25 Consecutive Original Summer Temperatures (y)')
plt.xlabel('Group Index (each group is 25 elements)')
plt.ylabel('Average Temperature')
plt.grid(True)
plt.xticks(range(len(y))) # Ensure all group indices are shown
plt.show()

# %% [markdown]
# ## Analyze Line Plot Information
#
# ### Subtask:
# Describe the kind of information that can be obtained from the line plot of the averages of the sorted `summer_temp` data.

# %% [markdown]
# From the line plot of the averages of 25 consecutive sorted elements, you can observe:
#
# *   **Trend**: The plot will show a clear increasing trend. Since we sorted `summer_temp` first, taking averages of consecutive blocks will naturally result in increasing average values.
# *   **Data Distribution/Spread**: It gives a coarse-grained view of the temperature distribution. Each point represents a segment of the overall data range.
# *   **Range**: The first point in the plot will indicate the average of the lowest 25 temperatures, and the last point will indicate the average of the highest 25 temperatures. This shows the range covered by the data in these averaged segments.

# %% [markdown]
# Q6.Repeat above step for summer_temp, store summary in object y and this time use scatter plot to plot values. What kind of information do u get about the data?

# %% [markdown]
# ## Calculate Averages for Original Data
#
# ### Subtask:
# Calculate the average of 25 consecutive elements from the original `summer_temp` array and store the results in a new object named `y`.

# %% [markdown]
# **Reasoning**:
# The subtask requires calculating the average of 25 consecutive elements from the original `summer_temp` array and storing them in an object `y`. I will implement the specified steps in a code block: define `window_size`, iterate through `summer_temp` to get 25-element slices, calculate the mean of each slice, store these means in a list, convert the list to a NumPy array `y`, and then print `y`.

# %%
window_size = 25
y = []

for i in range(0, len(summer_temp), window_size):
    # Select a slice of 25 consecutive elements
    current_slice = summer_temp[i:i + window_size]
    # Calculate the mean of the slice
    average = np.mean(current_slice)
    # Append the average to the list
    y.append(average)

y = np.array(y)

print("Averages of 25 consecutive elements from original summer_temp (y):"), y
# Out:
# Averages of 25 consecutive elements from original summer_temp (y):
# (None, array([30.26692819, 29.1572242 , 30.46867066, 29.55131174]))

# %% [markdown]
# **Reasoning**:
# The previous step successfully calculated the averages and stored them in `y`. Now, as per the main task, I need to create a scatter plot of these `y` values to visualize them.

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(len(x)), x, marker='o', linestyle='-', color='blue')
plt.title('Line Plot of Averages of Sorted Summer Temperatures')
plt.xlabel('Group Index')
plt.ylabel('Average Temperature')
plt.grid(True)
plt.xticks(range(len(x))) # Ensure all group indices are shown
plt.show()

# %% [markdown]
# ### Analysis of the Scatter Plot (y) vs. Line Plot (x) and Overall Insights:
#
# **Scatter Plot of `y` (Averages from Original `summer_temp`):**
# The scatter plot for `y` (averages of 25 consecutive elements from the *original*, unsorted `summer_temp` array) shows the following:
# *   **Lack of Clear Trend:** Unlike the line plot of `x`, there is no obvious increasing or decreasing trend in the `y` values. The points appear more randomly distributed across a certain range.
# *   **Fluctuation Around Mean:** The average values (y) fluctuate, suggesting that the original `summer_temp` data did not have a strong inherent ordering or trend over consecutive blocks. Each average represents the mean of a random segment of the original data.
# *   **Representation of Central Tendency:** Each point still represents a local average, providing a coarse view of the central tendency within those 25-element segments of the *original* sequence.
# *   **Consistency:** The values in `y` are relatively close to the overall mean of `summer_temp` (which was around 30), indicating that the original data was indeed generated from a normal distribution with that mean, and consecutive segments also hover around that mean.
#
# **Comparison with Line Plot of `x` (Averages from `sorted_summer_temp`):**
# *   **Trend:** The line plot of `x` (from sorted data) showed a clear, monotonic increasing trend. This is because `x` was derived from data already ordered from smallest to largest. The scatter plot of `y` (from unsorted data) does *not* show such a trend, highlighting the impact of sorting on visualizing sequential averages.
# *   **Interpretation:** The line plot of `x` gives insights into the *distribution* and *range* of the `summer_temp` values when ordered. The scatter plot of `y` gives insights into the *randomness* and *average behavior* of `summer_temp` as it was originally generated, confirming its uniform distribution around a central value without any inherent sequence-dependent pattern.
#
# **Overall Insights about `summer_temp` data:**
# 1.  **Nature of Data:** The `summer_temp` array consists of random numbers (specifically, from a normal distribution). This is evident from the `y` scatter plot which shows no discernible pattern or trend over consecutive original segments.
# 2.  **Central Tendency:** Both plots, in their own way, confirm that the data is centered around a mean of approximately 30, with most values falling within a reasonable range around this mean, which is characteristic of a normal distribution.
# 3.  **Impact of Sorting:** The stark difference between the `x` line plot and the `y` scatter plot clearly demonstrates how preprocessing (like sorting) can reveal different characteristics of the underlying data. Sorting allowed us to visualize the *range* and *spread* of the data by showing how averages increase from the lowest to the highest values, while using the original unsorted data shows the *randomness* and *consistency* of the mean across arbitrary segments.

# %% [markdown]
# ### Analysis of the Scatter Plot (y) vs. Line Plot (x) and Overall Insights:
#
# **Scatter Plot of `y` (Averages from Original `summer_temp`):**
# The scatter plot for `y` (averages of 25 consecutive elements from the *original*, unsorted `summer_temp` array) shows the following:
# *   **Lack of Clear Trend:** Unlike the line plot of `x`, there is no obvious increasing or decreasing trend in the `y` values. The points appear more randomly distributed across a certain range.
# *   **Fluctuation Around Mean:** The average values (y) fluctuate, suggesting that the original `summer_temp` data did not have a strong inherent ordering or trend over consecutive blocks. Each average represents the mean of a random segment of the original data.
# *   **Representation of Central Tendency:** Each point still represents a local average, providing a coarse view of the central tendency within those 25-element segments of the *original* sequence.
# *   **Consistency:** The values in `y` are relatively close to the overall mean of `summer_temp` (which was around 30), indicating that the original data was indeed generated from a normal distribution with that mean, and consecutive segments also hover around that mean.
#
# **Comparison with Line Plot of `x` (Averages from `sorted_summer_temp`):**
# *   **Trend:** The line plot of `x` (from sorted data) showed a clear, monotonic increasing trend. This is because `x` was derived from data already ordered from smallest to largest. The scatter plot of `y` (from unsorted data) does *not* show such a trend, highlighting the impact of sorting on visualizing sequential averages.
# *   **Interpretation:** The line plot of `x` gives insights into the *distribution* and *range* of the `summer_temp` values when ordered. The scatter plot of `y` gives insights into the *randomness* and *average behavior* of `summer_temp` as it was originally generated, confirming its uniform distribution around a central value without any inherent sequence-dependent pattern.
#
# **Overall Insights about `summer_temp` data:**
# 1.  **Nature of Data:** The `summer_temp` array consists of random numbers (specifically, from a normal distribution). This is evident from the `y` scatter plot which shows no discernible pattern or trend over consecutive original segments.
# 2.  **Central Tendency:** Both plots, in their own way, confirm that the data is centered around a mean of approximately 30, with most values falling within a reasonable range around this mean, which is characteristic of a normal distribution.
# 3.  **Impact of Sorting:** The stark difference between the `x` line plot and the `y` scatter plot clearly demonstrates how preprocessing (like sorting) can reveal different characteristics of the underlying data. Sorting allowed us to visualize the *range* and *spread* of the data by showing how averages increase from the lowest to the highest values, while using the original unsorted data shows the *randomness* and *consistency* of the mean across arbitrary segments.

# %% [markdown]
# Q7.plot summer_temp and y together in same line plot.

# %%
plt.figure(figsize=(14, 7))

# Plot summer_temp as a line to show individual data points
plt.plot(np.arange(len(summer_temp)), summer_temp, color='gray', linestyle=':', alpha=0.7, label='Individual Summer Temperatures')

# Calculate x-coordinates for y, representing the midpoint of each 25-element window
window_size = 25
x_for_y = np.arange(len(y)) * window_size + window_size / 2

# Plot y as a more prominent line with markers
plt.plot(x_for_y, y, color='red', linestyle='-', marker='o', markersize=7, label='Average of 25 Consecutive Elements (y)')

plt.title('Individual Summer Temperatures vs. Averages of Consecutive Elements')
plt.xlabel('Data Index / Group Midpoint')
plt.ylabel('Temperature')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# From this combined line plot, you can observe:
#
# *   **Individual Variability (summer_temp)**: The gray dotted line shows the full range and fluctuation of the individual `summer_temp` readings. You can see how widely temperatures vary from one measurement to the next.
# *   **Smoothed Trend (y)**: The red solid line with markers represents the averages (`y`) of consecutive 25-element blocks. This line provides a smoothed view, highlighting the overall central tendency in different segments of the original, unsorted data. Even though `summer_temp` is random, its averages `y` still hover around the true mean of the normal distribution (around 30).
# *   **Relationship**: The plot clearly illustrates how the average (`y`) acts as a central value for the group of individual temperatures it represents. The individual points of `summer_temp` are scattered around their respective `y` average values.
# *   **Consistency of Mean**: Both lines generally stay around the mean of 30, which confirms the normal distribution from which `summer_temp` was generated. The averages in `y` fluctuate less dramatically than the individual `summer_temp` points.

# %% [markdown]
# **Conclusion**:
#
# Thus we have learned abou basics of ploting using matplotlib.
